# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
from IPython.display import HTML
from IPython.display import display
import requests # library to handle requests

# %%
base_url='https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
r=requests.get(base_url)
#col_names= ['10E', '10M', '11E','11M','12E','12M','13E','13M','14E','14M',
#            '15E','15M','16E','16M','17E','17M','MN','Saint_Paul']
#df= pd.DataFrame(columns=col_names, data=r.json()[1:])
#r.json()[0:]
r.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-895e85e116fe> in <module>
#       5 #df= pd.DataFrame(columns=col_names, data=r.json()[1:])
#       6 #r.json()[0:]
# ----> 7 r.dtypes
#
# AttributeError: 'Response' object has no attribute 'dtypes'

# %%
{"objectIdFieldName":"OBJECTID","uniqueIdField":{"name":"OBJECTID","isSystemMaintained":true},"globalIdFieldName":"","geometryType":"esriGeometryPoint","spatialReference":{"wkid":4326,"latestWkid":4326},"fields":[{"name":"apn","type":"esriFieldTypeString","alias":"apn","sqlType":"sqlTypeOther","length":25,"domain":null,"defaultValue":null},{"name":"OBJECTID","type":"esriFieldTypeOID","alias":"OBJECTID","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"licenseNumber","type":"esriFieldTypeString","alias":"licenseNumber","sqlType":"sqlTypeOther","length":55,"domain":null,"defaultValue":null},{"name":"category","type":"esriFieldTypeString","alias":"category","sqlType":"sqlTypeOther","length":10,"domain":null,"defaultValue":null},{"name":"milestone","type":"esriFieldTypeString","alias":"milestone","sqlType":"sqlTypeOther","length":10,"domain":null,"defaultValue":null},{"name":"tier","type":"esriFieldTypeString","alias":"tier","sqlType":"sqlTypeOther","length":10,"domain":null,"defaultValue":null},{"name":"status","type":"esriFieldTypeString","alias":"status","sqlType":"sqlTypeOther","length":30,"domain":null,"defaultValue":null},{"name":"issueDate","type":"esriFieldTypeDate","alias":"issueDate","sqlType":"sqlTypeOther","length":8,"domain":null,"defaultValue":null},{"name":"expirationDate","type":"esriFieldTypeDate","alias":"expirationDate","sqlType":"sqlTypeOther","length":8,"domain":null,"defaultValue":null},{"name":"address","type":"esriFieldTypeString","alias":"address","sqlType":"sqlTypeOther","length":106,"domain":null,"defaultValue":null},{"name":"ownerName","type":"esriFieldTypeString","alias":"ownerName","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"ownerAddress1","type":"esriFieldTypeString","alias":"ownerAddress1","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"ownerAddress2","type":"esriFieldTypeString","alias":"ownerAddress2","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"ownerCity","type":"esriFieldTypeString","alias":"ownerCity","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"ownerState","type":"esriFieldTypeString","alias":"ownerState","sqlType":"sqlTypeOther","length":30,"domain":null,"defaultValue":null},{"name":"ownerZip","type":"esriFieldTypeString","alias":"ownerZip","sqlType":"sqlTypeOther","length":25,"domain":null,"defaultValue":null},{"name":"ownerPhone","type":"esriFieldTypeString","alias":"ownerPhone","sqlType":"sqlTypeOther","length":30,"domain":null,"defaultValue":null},{"name":"ownerEmail","type":"esriFieldTypeString","alias":"ownerEmail","sqlType":"sqlTypeOther","length":254,"domain":null,"defaultValue":null},{"name":"applicantName","type":"esriFieldTypeString","alias":"applicantName","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"applicantAddress1","type":"esriFieldTypeString","alias":"applicantAddress1","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"applicantAddress2","type":"esriFieldTypeString","alias":"applicantAddress2","sqlType":"sqlTypeOther","length":200,"domain":null,"defaultValue":null},{"name":"applicantCity","type":"esriFieldTypeString","alias":"applicantCity","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"applicantState","type":"esriFieldTypeString","alias":"applicantState","sqlType":"sqlTypeOther","length":30,"domain":null,"defaultValue":null},{"name":"applicantZip","type":"esriFieldTypeString","alias":"applicantZip","sqlType":"sqlTypeOther","length":25,"domain":null,"defaultValue":null},{"name":"applicantPhone","type":"esriFieldTypeString","alias":"applicantPhone","sqlType":"sqlTypeOther","length":30,"domain":null,"defaultValue":null},{"name":"applicantEmail","type":"esriFieldTypeString","alias":"applicantEmail","sqlType":"sqlTypeOther","length":254,"domain":null,"defaultValue":null},{"name":"licensedUnits","type":"esriFieldTypeInteger","alias":"licensedUnits","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"ward","type":"esriFieldTypeString","alias":"ward","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"neighborhoodDesc","type":"esriFieldTypeString","alias":"neighborhoodDesc","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"communityDesc","type":"esriFieldTypeString","alias":"communityDesc","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"policePrecinct","type":"esriFieldTypeString","alias":"policePrecinct","sqlType":"sqlTypeOther","length":100,"domain":null,"defaultValue":null},{"name":"shortTermRental","type":"esriFieldTypeString","alias":"shortTermRental","sqlType":"sqlTypeOther","length":10,"domain":null,"defaultValue":null},{"name":"latitude","type":"esriFieldTypeDouble","alias":"latitude","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"longitude","type":"esriFieldTypeDouble","alias":"longitude","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"xWebMercator","type":"esriFieldTypeDouble","alias":"xWebMercator","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"yWebMercator","type":"esriFieldTypeDouble","alias":"yWebMercator","sqlType":"sqlTypeOther","domain":null,"defaultValue":null}]

# %%
base_url

patients_df = pd.read_json(base_url)
patients_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c5eb1e64ccd0> in <module>
#       1 base_url
#       2
# ----> 3 patients_df = pd.read_json(base_url)
#       4 patients_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ...

# %%
import geojson
with open('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json') as f:
    gj = geojson.load(f)
#features = gj['features'][0]

gj
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-f75fff9adae3> in <module>
#       1 import geojson
# ----> 2 with open('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json') as f:
#       3     gj = geojson.load(f)
#       4 #features = gj['features'][0]
#       5
#
# OSError: [Errno 22] Invalid argument: 'https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'

# %%
import pandas as pd

df = pd.read_json('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b7f258427daf> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')
#       4
#       5 print(df.to_string())
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# ...

# %%
import pandas as pd
import json
import os

#os.chdir('/Users/nicolas/Downloads')

# Reading the json as a dict
with open('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json') as json_data:
    data = json.load(json_data)

# using the from_dict load function. Note that the 'orient' parameter 
#is not using the default value (or it will give the same error that you got before)
# We transpose the resulting df and set index column as its index to get this result
pd.DataFrame.from_dict(data, orient='index').T.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-bc2b30213340> in <module>
#       6
#       7 # Reading the json as a dict
# ----> 8 with open('https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json') as json_data:
#       9     data = json.load(json_data)
#      10
#
# OSError: [Errno 22] Invalid argument: 'https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'

# %%
import pandas as pd
import json
from urllib.request import urlopen

json_file = "https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Active_Rental_Licenses/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json"
data = urlopen(json_file).read()
raw_json = json.loads(data)
formatted_json = [feature['attributes'] for feature in raw_json['features']]

df = pd.DataFrame(formatted_json)

df
# Out:
#        OBJECTID                     address            apn  \
# 0             1           5924 OLIVER AVE S  2102824320092
# 1             2          5013 ALDRICH AVE N  1211821240019
# 2             3          3434 LYNDALE AVE N  1002924220117
# 3             4           2001 GLENWOOD AVE  2102924330058
# 4             5          2311 LYNDALE AVE N  1602924110043
# 5             6             923 25TH AVE SE  1902923240006
# 6             7           4647 BRYANT AVE N  1211821340060
# 7             8          3645 FREMONT AVE N  0402924430142
# 8             9              3117 38TH ST E  0702823220032
# 9            10             627 QUEEN AVE N  2002924140133
# 10           11           3601 NEWTON AVE N  0402924330210
# 11           12  315 WEST RIVER PKWY N #105  2202924110102
# 12           13           4517 ABBOTT AVE S  0802824340171
# 13           14     1704 1/2 FILLMORE ST NE  1302924220017
# 14           15           1014 PORTLAND AVE  2602924230162
# ...
